# %% [markdown]
# ### Synthetic Dataset Generation
# Mico Ellerich M. Comia
#
# ---
#
# - GENERATE 1000 (ONE THOUSAND) RECORDS USING THE SKLEARN LIBRARY
# - PREPARE A QUICK DIAGRAM / CHART OF THE PROPERTIES OF THE DATASET USING MATPLOTLIB
# - PERFORM THE TRAIN-TEST SPLIT (TRAIN-VALIDATION-TEST)
# - STORE THE FILES INSIDE A DIRECTORY FOR LATER USE
#
# References:
# 1. https://stackabuse.com/generating-synthetic-data-with-numpy-and-scikit-learn/
# 2. https://towardsdatascience.com/https-medium-com-faizanahemad-generating-synthetic-classification-data-using-scikit-1590c1632922

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.datasets as dt

from sklearn.model_selection import train_test_split

# %% [markdown]
# #### I. Generating 1000 records
# ---

# %%
X,y = dt.make_classification(n_samples = 1000, n_features = 3, 
                             n_informative = 2, n_redundant = 1,
                            n_classes = 2, n_clusters_per_class = 1,
                            random_state = 43)

# %%
print(f"Size of X: {len(X)}")
print(f"Size of Y: {len(y)}")
# Out:
# Size of X: 1000
# Size of Y: 1000

# %% [markdown]
# #### II. Diagram/chart of the properties
# ---

# %%
plt.scatter(X[:,0], X[:,1], c=y)

# %% [markdown]
# ### III. Train-Validation-Test split
# ---

# %%
# 80-20 Train-Test
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.2,
                                                    random_state = 43)

# %%
# 80-20 Train-Test
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size = 0.25,
                                                  random_state = 43)

# %%
print(f"Size of X_train: {len(X_train)}")
print(f"Size of y_train: {len(y_train)}")
print(f"Size of X_val: {len(X_val)}")
print(f"Size of y_val: {len(y_val)}")
print(f"Size of X_test: {len(X_test)}")
print(f"Size of y_test: {len(y_test)}")
# Out:
# Size of X_train: 600
# Size of y_train: 600
# Size of X_val: 200
# Size of y_val: 200
# Size of X_test: 200
# Size of y_test: 200

# %% [markdown]
# ### IV. Storing files
# ---

# %%
df_X_train = pd.DataFrame(X_train, columns = ['X1', 'X2', 'X3'])
df_X_val = pd.DataFrame(X_val, columns = ['X1', 'X2', 'X3'])
df_X_test= pd.DataFrame(X_test, columns = ['X1', 'X2', 'X3'])
df_y_train = pd.DataFrame(y_train, columns = ['Y'])
df_y_val = pd.DataFrame(y_val, columns = ['Y'])
df_y_test = pd.DataFrame(y_test, columns = ['Y'])

# %%
df_X_train
# Out:
#            X1        X2        33
# 0   -1.411310  1.202492 -2.530413
# 1    1.089605 -1.133823  2.151078
# 2    0.601844 -1.086300  1.630334
# 3   -1.595333  0.190073 -1.736504
# 4    1.605606 -1.028199  2.552120
# ..        ...       ...       ...
# 595  2.879002 -0.688120  3.465484
# 596 -0.531913  0.748684 -1.237706
# 597  1.318292 -0.748730  2.003659
# 598 -1.827628  1.332549 -3.060906
# 599  1.547812 -1.175601  2.637514
#
# [600 rows x 3 columns]

# %%
df_X_val
# Out:
#            X1        X2        33
# 0    1.041472 -1.285985  2.250457
# 1    1.214033 -0.994141  2.138004
# 2   -0.485299  1.301954 -1.724111
# 3    0.496872  2.095097 -1.529879
# 4   -0.769509  1.113770 -1.820040
# ..        ...       ...       ...
# 195  0.241885 -0.819250  1.023055
# 196 -1.355438  1.776600 -3.027831
# 197  0.874026 -1.161116  1.967345
# 198  0.977286 -1.310726  2.211722
# 199  0.457950 -1.198661  1.598187
#
# [200 rows x 3 columns]

# %%
df_X_test
# Out:
#            X1        X2        33
# 0    0.369974 -1.090837  1.408862
# 1    0.987166 -0.882407  1.809643
# 2    1.137689 -1.136423  2.200409
# 3    0.296085 -1.626090  1.851383
# 4   -1.657518  0.965085 -2.542015
# ..        ...       ...       ...
# 195 -2.372103  0.647719 -2.932947
# 196  0.811994 -1.293353  2.034034
# 197  0.484136 -1.216269  1.640617
# 198  0.743841 -1.017233  1.702247
# 199 -1.327061  1.538004 -2.770853
#
# [200 rows x 3 columns]

# %%
df_y_train
# Out:
#      Y
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# ..  ..
# 595  0
# 596  1
# 597  0
# 598  1
# 599  0
#
# [600 rows x 1 columns]

# %%
df_y_val
# Out:
#      Y
# 0    0
# 1    0
# 2    1
# 3    1
# 4    1
# ..  ..
# 195  0
# 196  1
# 197  0
# 198  0
# 199  0
#
# [200 rows x 1 columns]

# %%
df_y_test
# Out:
#      Y
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# ..  ..
# 195  1
# 196  0
# 197  0
# 198  0
# 199  1
#
# [200 rows x 1 columns]

# %%
# Saving as CSV files
df_X_train.to_csv("data/X_train.csv", index = False)
df_X_val.to_csv("data/X_val.csv", index = False)
df_X_test.to_csv("data/X_test.csv", index = False)
df_y_train.to_csv("data/y_train.csv", index = False)
df_y_val.to_csv("data/y_val.csv", index = False)
df_y_test.to_csv("data/y_test.csv", index = False)
